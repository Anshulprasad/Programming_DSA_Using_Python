# %% [markdown]
# linear structures
#
# usorted list\
# insert O(1)\
# delete_max O(n)
#
# sorted list\
# insert O(n)\
# delete_max O(1)
#
# processing n jobs take time O(n^2)

# %% [markdown]
# Heap - spectial binary tree\
# Balanced = n node tree has height log(n)
#
# insert O(log(n))\
# delete_max O(log(n))
#
# processing n jobs take time O(nlog(n))

# %% [markdown]
#                           50
#                         /    \
#                       30      40
#                     /    \   /   \
#                    21    35 37     50
#                 /
#                 11
