# %% [markdown]
# operations on numbers

# %%
print(7/3)
print(7.0/3)
print(7/3.0)
print(7.0/3.0)
print()

print(9//5)
print(9.0//5)
print(9//5.0)
print(9.0//5.0)
print()

print(9%5)
print(9.0%5)
print(9%5.0)
print(9.0%5.0)
print()

print(3**4)
print(3.0**4)
print(3**4.0)
print(3.0**4.0)
# Out:
# 2.3333333333333335
# 2.3333333333333335
# 2.3333333333333335
# 2.3333333333333335
#
# 1
# 1.0
# 1.0
# 1.0
#
# 4
# 4.0
# 4.0
# 4.0
#
# 81
# 81.0
# 81.0
# 81.0

# %%
from math import *

print(log(2))
print(sqrt(2))
print(sin(3.14/2))
# Out:
# 0.6931471805599453
# 1.4142135623730951
# 0.9999996829318346

# %% [markdown]
# names, values and types

# %%
i = 5
print(type(i))

j = 5.0
print(type(j))

k = True
print(type(k))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# Example

# %%
def divides(m,n):
    if n%m == 0:
        return True
    else:
        return False

def even(n):
    return divides(2,n)

def odd(n):
    return not divides(2,n)

print(odd(7),odd(6),even(7),even(6))
# Out:
# True False False True
