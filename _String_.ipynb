# %%
city = 'Chennai'
print(city)

title = "hello Anshul's friend"
print(title)

dialoge = """Anshul's friend has said "take the medicine on time\""""
print(dialoge)

dialoge = '''Anshul's friend has said "take the medicine on time"\''''
print(dialoge)

myquote = '''first line
second line
third line'''
print(myquote)
# Out:
# Chennai
# hello Anshul's friend
# Anshul's friend has said "take the medicine on time"
# Anshul's friend has said "take the medicine on time"'
# first line
# second line
# third line

# %% [markdown]
# operations on string

# %%
s = "hello"
t = s + ", there"
print(t)
print(len(s))
# Out:
# hello, there
# 5

# %% [markdown]
# extracting substring

# %%
s = "hello"

print(s[3:1])
print(s[:2])
# Out:
# he

# %% [markdown]
# strings are immutable

# %%
s[3:] = "p!"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s[3:] = "p!"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# instead, use slice and concatenation

# %%
s = s[:3] + "p!"

print(type(s))
print(s)
# Out:
# <class 'str'>
# help!

# %%
print(s[0])
print(s[0:1])
# Out:
# h
# h
